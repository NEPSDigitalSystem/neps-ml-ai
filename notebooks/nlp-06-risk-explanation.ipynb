# %%
risk_score = {
    "low":0,
    "moderate":1,
    "high":2
}

df["risk_target"] = df[
    "severity_level"
].map(risk_score)

# %%
features = [

    "word_count",
    "sentiment_score"

]

# %%
from xgboost import XGBClassifier

# %%
risk_target
